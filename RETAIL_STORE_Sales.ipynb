# %%
import pandas as pd

# %%
jk=pd.read_csv("/content/retail_store_sales_dataset.csv")

# %%
jk.head()
# Out:
#    transaction_id       city         store product_category product_name  \
# 0            5001       Pune  Central Mall       Home Decor   Face Cream
# 1            5002  Bangalore   City Center       Home Decor    Wall Lamp
# 2            5003  Hyderabad  Central Mall         Clothing        Jeans
# 3            5004  Hyderabad  Smart Bazaar       Home Decor        Mixer
# 4            5005  Hyderabad  Central Mall           Beauty   Headphones
#
#    unit_price  quantity customer_type payment_method  discount_percent  \
# 0        2386         4     Returning           Card                15
# 1        1383         1           New           Card                10
# 2        4937         1     Returning            UPI                 5
# 3        1470         2     Returning            UPI                10
# 4        2688         1           New           Cash                10
#
#    total_sale  discount_amount  final_amount
# 0        9544          1431.60       8112.40
# ...

# %%
jk.tail()
# Out:
#      transaction_id       city         store product_category product_name  \
# 215            5216  Hyderabad  Smart Bazaar       Home Decor        Jeans
# 216            5217     Mysore  Urban Retail           Beauty     Rice Bag
# 217            5218       Pune  Smart Bazaar      Electronics        Jeans
# 218            5219    Chennai  Urban Retail        Groceries      T-shirt
# 219            5220    Chennai  Central Mall       Home Decor   Headphones
#
#      unit_price  quantity customer_type payment_method  discount_percent  \
# 215        1809         3           New           Card                15
# 216        4696         1     Returning           Cash                15
# 217        3699         4           New           Cash                 0
# 218        2845         4           New            UPI                15
# 219        2783         1     Returning           Card                10
#
#      total_sale  discount_amount  final_amount
# ...

# %%
jk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    220 non-null    int64
#  1   city              220 non-null    object
#  2   store             220 non-null    object
#  3   product_category  220 non-null    object
#  4   product_name      220 non-null    object
#  5   unit_price        220 non-null    int64
#  6   quantity          220 non-null    int64
#  7   customer_type     220 non-null    object
#  8   payment_method    220 non-null    object
#  9   discount_percent  220 non-null    int64
#  10  total_sale        220 non-null    int64
#  11  discount_amount   220 non-null    float64
#  12  final_amount      220 non-null    float64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 22.5+ KB

# %%
jk.shape
# Out:
# (220, 13)

# %%
jk["city"].unique()
# Out:
# array(['Pune', 'Bangalore', 'Hyderabad', 'Mysore', 'Chennai'],
#       dtype=object)

# %%
jk["product_category"].unique()
# Out:
# array(['Home Decor', 'Clothing', 'Beauty', 'Electronics', 'Groceries'],
#       dtype=object)

# %%
len(jk["product_category"].unique())
# Out:
# 5

# %%
jk.head(10)
# Out:
#    transaction_id       city         store product_category product_name  \
# 0            5001       Pune  Central Mall       Home Decor   Face Cream
# 1            5002  Bangalore   City Center       Home Decor    Wall Lamp
# 2            5003  Hyderabad  Central Mall         Clothing        Jeans
# 3            5004  Hyderabad  Smart Bazaar       Home Decor        Mixer
# 4            5005  Hyderabad  Central Mall           Beauty   Headphones
# 5            5006     Mysore  Urban Retail      Electronics     Rice Bag
# 6            5007  Hyderabad    Metro Mart       Home Decor    Wall Lamp
# 7            5008    Chennai  Central Mall      Electronics        Mixer
# 8            5009       Pune  Central Mall      Electronics    Wall Lamp
# 9            5010  Bangalore   City Center       Home Decor    Wall Lamp
#
#    unit_price  quantity customer_type payment_method  discount_percent  \
# 0        2386         4     Returning           Card                15
# ...

# %%
jk.describe()
# Out:
#        transaction_id   unit_price    quantity  discount_percent  \
# count      220.000000   220.000000  220.000000        220.000000
# mean      5110.500000  2608.868182    2.418182         10.181818
# std         63.652704  1333.082940    1.133805          6.652746
# min       5001.000000   228.000000    1.000000          0.000000
# 25%       5055.750000  1470.750000    1.000000          5.000000
# 50%       5110.500000  2655.000000    2.000000         10.000000
# 75%       5165.250000  3639.750000    3.000000         15.000000
# max       5220.000000  4995.000000    4.000000         20.000000
#
#          total_sale  discount_amount  final_amount
# count    220.000000       220.000000    220.000000
# mean    6209.959091       628.017045   5581.942045
# std     4602.416562       676.102942   4205.370713
# min      229.000000         0.000000    183.200000
# 25%     2690.250000       142.912500   2395.125000
# 50%     4526.000000       400.500000   3991.175000
# ...

# %%
jk["product_category"].unique()
# Out:
# array(['Home Decor', 'Clothing', 'Beauty', 'Electronics', 'Groceries'],
#       dtype=object)

# %%
jk["product_category"].value_counts().idxmax()
# Out:
# 'Groceries'

# %%
jk.groupby("product_category")["quantity"].sum().idxmax()
# Out:
# 'Groceries'

# %%
jk.groupby("store")["total_sale"].sum().idxmax()
# Out:
# 'Smart Bazaar'

# %%
jk["payment_method"].max()
# Out:
# 'UPI'

# %%
jk["city"].value_counts().idxmax()
# Out:
# 'Hyderabad'

# %%
jk["final_amount"].mean()
# Out:
# np.float64(5581.942045454545)

# %%
jk["total_sale"].max()
# Out:
# 19900

# %%
jk.groupby("city")["final_amount"].sum().idxmax()
# Out:
# 'Hyderabad'

# %%
jk["payment_method"].max()
# Out:
# 'UPI'

# %%
jk.groupby("customer_type")["final_amount"].sum()
# Out:
# customer_type
# New          671836.35
# Returning    556190.90
# Name: final_amount, dtype: float64

# %%
jk["payment_method"].value_counts().idxmax()
# Out:
# 'Card'

# %%
jk.groupby("customer_type")["final_amount"].sum().idxmax()
# Out:
# 'New'

# %%
jk.groupby("product_category")["final_amount"].sum().idxmax()
# Out:
# 'Groceries'

# %%
jk.groupby("store")["discount_amount"].sum().idxmax()
# Out:
# 'Smart Bazaar'

# %%
jk["product_name"].value_counts().idxmax()
# Out:
# 'Mixer'

# %%
jk.groupby("city")["final_amount"].max()
# Out:
# city
# Bangalore    15249.0
# Chennai      19000.0
# Hyderabad    16580.0
# Mysore       19900.0
# Pune         17474.4
# Name: final_amount, dtype: float64

# %%
# Which product sells the most units?
jk.groupby("product_category")["final_amount"].max()
# Out:
# product_category
# Beauty         16580.0
# Clothing       17474.4
# Electronics    19900.0
# Groceries      12988.8
# Home Decor     19000.0
# Name: final_amount, dtype: float64

# %%
# Which city has the highest average purchase value?
jk.groupby("city")["final_amount"].mean().idxmax()
# Out:
# 'Mysore'

# %%
# Which product category is most popular among returning customers?
cu_Returning=jk[jk["customer_type"]=="Returning"]
cu_Returning['customer_type']
# Out:
# 0      Returning
# 2      Returning
# 3      Returning
# 5      Returning
# 8      Returning
#          ...
# 211    Returning
# 212    Returning
# 213    Returning
# 216    Returning
# 219    Returning
# Name: customer_type, Length: 114, dtype: object

# %%
# Which product category is most popular among returning customers?
cu_Returning.groupby("product_category")["customer_type"].sum().idxmax()
# Out:
# 'Groceries'

# %%
# Which product category is most popular among returning customers?
cu_Returning["product_category"].value_counts().idxmax()
# Out:
# 'Groceries'

# %%
jk.head()
# Out:
#    transaction_id       city         store product_category product_name  \
# 0            5001       Pune  Central Mall       Home Decor   Face Cream
# 1            5002  Bangalore   City Center       Home Decor    Wall Lamp
# 2            5003  Hyderabad  Central Mall         Clothing        Jeans
# 3            5004  Hyderabad  Smart Bazaar       Home Decor        Mixer
# 4            5005  Hyderabad  Central Mall           Beauty   Headphones
#
#    unit_price  quantity customer_type payment_method  discount_percent  \
# 0        2386         4     Returning           Card                15
# 1        1383         1           New           Card                10
# 2        4937         1     Returning            UPI                 5
# 3        1470         2     Returning            UPI                10
# 4        2688         1           New           Cash                10
#
#    total_sale  discount_amount  final_amount
# 0        9544          1431.60       8112.40
# ...
